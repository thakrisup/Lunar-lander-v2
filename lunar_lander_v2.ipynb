# %% [markdown]
# # MVP Pipeline

# %% [markdown]
# ## Step 1 : Install dependencies

# %%
import gym
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 2 : setup RL environment

# %%
# Create environment
env_name = 'LunarLander-v2'
env = gym.make(env_name)

# %% [markdown]
# ## Step 3 : RL model training

# %%
# Instantiate the agent
model = DQN('MlpPolicy', env, verbose=1)
## exploration_final_eps=0.1, target_update_interval=250

# Train the agent
model.learn(total_timesteps=int(1e6))
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95       |
# |    ep_rew_mean      | -135     |
# |    exploration rate | 0.996    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4961     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 380      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -158     |
# |    exploration rate | 0.992    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 6215     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 842      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | -146     |
# |    exploration rate | 0.988    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 6876     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1279     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -176     |
# |    exploration rate | 0.985    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 7259     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1624     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -181     |
# |    exploration rate | 0.98     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 7599     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2074     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -192     |
# |    exploration rate | 0.976    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 7832     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2494     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -195     |
# |    exploration rate | 0.973    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 7949     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2860     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -188     |
# |    exploration rate | 0.969    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 8075     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3287     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.966    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 8188     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3592     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.5     |
# |    ep_rew_mean      | -177     |
# |    exploration rate | 0.963    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 8300     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3939     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.3     |
# |    ep_rew_mean      | -184     |
# |    exploration rate | 0.959    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 8392     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4327     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.3     |
# |    ep_rew_mean      | -183     |
# |    exploration rate | 0.955    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 8451     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4719     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.2     |
# |    ep_rew_mean      | -183     |
# |    exploration rate | 0.952    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 8461     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5105     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.1     |
# |    ep_rew_mean      | -189     |
# |    exploration rate | 0.948    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 8477     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5494     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.3     |
# |    ep_rew_mean      | -195     |
# |    exploration rate | 0.944    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 8460     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.8     |
# |    ep_rew_mean      | -193     |
# |    exploration rate | 0.94     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 8471     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6320     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.8     |
# |    ep_rew_mean      | -189     |
# |    exploration rate | 0.937    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 8525     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6649     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.4     |
# |    ep_rew_mean      | -188     |
# |    exploration rate | 0.934    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 8549     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6938     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.4     |
# |    ep_rew_mean      | -188     |
# |    exploration rate | 0.93     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 8524     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7326     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | -187     |
# |    exploration rate | 0.927    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 8538     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7640     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.2     |
# |    ep_rew_mean      | -186     |
# |    exploration rate | 0.924    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 8568     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7995     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -182     |
# |    exploration rate | 0.921    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 8615     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8281     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -184     |
# |    exploration rate | 0.918    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 8646     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8630     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -187     |
# |    exploration rate | 0.914    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 8670     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9021     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -185     |
# |    exploration rate | 0.911    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 8697     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9372     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -185     |
# |    exploration rate | 0.907    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 8694     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9764     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -185     |
# |    exploration rate | 0.904    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 8695     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10110    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -187     |
# |    exploration rate | 0.901    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 8720     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10397    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -186     |
# |    exploration rate | 0.897    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 8738     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10792    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -182     |
# |    exploration rate | 0.895    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 8763     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11100    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89       |
# |    ep_rew_mean      | -181     |
# |    exploration rate | 0.892    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 8793     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11393    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.1     |
# |    ep_rew_mean      | -178     |
# |    exploration rate | 0.888    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 8803     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.4     |
# |    ep_rew_mean      | -177     |
# |    exploration rate | 0.885    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 8813     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12125    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -184     |
# |    exploration rate | 0.881    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 8834     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12517    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -185     |
# |    exploration rate | 0.878    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 8840     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12862    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.8     |
# |    ep_rew_mean      | -181     |
# |    exploration rate | 0.875    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 8845     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13208    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.8     |
# |    ep_rew_mean      | -181     |
# |    exploration rate | 0.871    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 8842     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.4     |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.867    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 8828     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.864    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 8828     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 14291    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.6     |
# |    ep_rew_mean      | -172     |
# |    exploration rate | 0.861    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 8829     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 14660    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.5     |
# |    ep_rew_mean      | -175     |
# |    exploration rate | 0.857    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 8674     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | -175     |
# |    exploration rate | 0.853    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 8656     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15447    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.4     |
# |    ep_rew_mean      | -175     |
# |    exploration rate | 0.849    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 8645     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15875    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.7     |
# |    ep_rew_mean      | -174     |
# |    exploration rate | 0.846    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 8645     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16197    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.4     |
# |    ep_rew_mean      | -173     |
# |    exploration rate | 0.843    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 8614     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16578    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.3     |
# |    ep_rew_mean      | -174     |
# |    exploration rate | 0.839    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 8599     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16928    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -180     |
# |    exploration rate | 0.836    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 8608     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17254    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -184     |
# |    exploration rate | 0.832    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 8623     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17653    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.828    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 8632     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18059    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -178     |
# |    exploration rate | 0.825    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 8648     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18386    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.822    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 8663     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18767    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.817    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 8655     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19212    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.814    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 8652     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19589    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -176     |
# |    exploration rate | 0.811    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 8657     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19930    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -184     |
# |    exploration rate | 0.807    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 8657     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 20309    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -185     |
# |    exploration rate | 0.803    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 8657     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 20685    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.6     |
# |    ep_rew_mean      | -188     |
# |    exploration rate | 0.799    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 8653     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 21128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -185     |
# |    exploration rate | 0.796    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 8648     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 21476    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -182     |
# |    exploration rate | 0.792    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 8647     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 21867    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -184     |
# |    exploration rate | 0.789    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 8655     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 22236    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -186     |
# |    exploration rate | 0.785    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 8660     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 22620    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -184     |
# |    exploration rate | 0.781    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 8668     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 23012    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -184     |
# |    exploration rate | 0.778    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 8671     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 23396    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95       |
# |    ep_rew_mean      | -184     |
# |    exploration rate | 0.774    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 8669     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 23796    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | -190     |
# |    exploration rate | 0.77     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 8666     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 24206    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.7     |
# |    ep_rew_mean      | -188     |
# |    exploration rate | 0.766    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 8672     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 24639    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96       |
# |    ep_rew_mean      | -189     |
# |    exploration rate | 0.762    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 8672     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 25042    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.2     |
# |    ep_rew_mean      | -189     |
# |    exploration rate | 0.759    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 8684     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 25394    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.2     |
# |    ep_rew_mean      | -187     |
# |    exploration rate | 0.756    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 8686     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 25719    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | -190     |
# |    exploration rate | 0.752    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 8691     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 26072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | -187     |
# |    exploration rate | 0.748    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 8686     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 26479    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.6     |
# |    ep_rew_mean      | -184     |
# |    exploration rate | 0.744    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 8691     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 26910    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.6     |
# |    ep_rew_mean      | -180     |
# |    exploration rate | 0.74     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 8694     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 27316    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96       |
# |    ep_rew_mean      | -182     |
# |    exploration rate | 0.737    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 8699     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 27655    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.6     |
# |    ep_rew_mean      | -188     |
# |    exploration rate | 0.734    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 8705     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 28043    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.6     |
# |    ep_rew_mean      | -189     |
# |    exploration rate | 0.73     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 8711     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 28428    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.2     |
# |    ep_rew_mean      | -189     |
# |    exploration rate | 0.726    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 8710     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 28832    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.3     |
# |    ep_rew_mean      | -185     |
# |    exploration rate | 0.722    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 8710     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 29219    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.6     |
# |    ep_rew_mean      | -189     |
# |    exploration rate | 0.719    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 8714     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 29593    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.2     |
# |    ep_rew_mean      | -181     |
# |    exploration rate | 0.716    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 8720     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 29932    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | -180     |
# |    exploration rate | 0.713    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 8730     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 30223    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.71     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 8737     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 30578    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -184     |
# |    exploration rate | 0.706    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 8742     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 30948    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -184     |
# |    exploration rate | 0.703    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 8747     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 31314    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -177     |
# |    exploration rate | 0.699    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 8754     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 31683    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | -173     |
# |    exploration rate | 0.696    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 8759     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 32044    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.9     |
# |    ep_rew_mean      | -175     |
# |    exploration rate | 0.692    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 8766     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 32400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -172     |
# |    exploration rate | 0.689    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 8778     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 32707    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -167     |
# |    exploration rate | 0.686    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 8782     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 33040    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -163     |
# |    exploration rate | 0.682    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 8786     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 33436    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -163     |
# |    exploration rate | 0.679    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 8790     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 33745    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -167     |
# |    exploration rate | 0.676    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 8794     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 34099    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -169     |
# |    exploration rate | 0.672    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 8793     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 34485    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -172     |
# |    exploration rate | 0.669    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 8798     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 34842    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -175     |
# |    exploration rate | 0.665    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 8801     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 35226    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -176     |
# |    exploration rate | 0.662    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 8806     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 35619    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -178     |
# |    exploration rate | 0.658    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 8812     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 35958    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -175     |
# |    exploration rate | 0.655    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 8815     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 36343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -173     |
# |    exploration rate | 0.652    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 8824     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 36677    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -172     |
# |    exploration rate | 0.648    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 8825     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 37057    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -175     |
# |    exploration rate | 0.644    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 8826     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 37464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -174     |
# |    exploration rate | 0.641    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 8835     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 37801    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89       |
# |    ep_rew_mean      | -177     |
# |    exploration rate | 0.638    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 8845     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 38120    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -174     |
# |    exploration rate | 0.634    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 8849     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 38511    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -177     |
# |    exploration rate | 0.631    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 8850     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 38857    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.4     |
# |    ep_rew_mean      | -172     |
# |    exploration rate | 0.628    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 8854     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 39167    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.4     |
# |    ep_rew_mean      | -167     |
# |    exploration rate | 0.625    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 8862     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 39522    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -167     |
# |    exploration rate | 0.62     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 8865     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 39975    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -169     |
# |    exploration rate | 0.617    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 8870     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 40292    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -169     |
# |    exploration rate | 0.614    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 8875     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 40601    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -174     |
# |    exploration rate | 0.61     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 8877     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 41032    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89       |
# |    ep_rew_mean      | -173     |
# |    exploration rate | 0.608    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 8884     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 41300    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -178     |
# |    exploration rate | 0.604    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 8884     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 41697    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -180     |
# |    exploration rate | 0.601    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 8886     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 42035    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.1     |
# |    ep_rew_mean      | -180     |
# |    exploration rate | 0.598    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 8892     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 42346    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.3     |
# |    ep_rew_mean      | -176     |
# |    exploration rate | 0.595    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 8899     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 42678    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.3     |
# |    ep_rew_mean      | -173     |
# |    exploration rate | 0.591    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 8901     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 43026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -175     |
# |    exploration rate | 0.587    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 8900     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 43486    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -175     |
# |    exploration rate | 0.583    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 8901     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 43888    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -170     |
# |    exploration rate | 0.58     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 8908     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 44191    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -170     |
# |    exploration rate | 0.577    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 8912     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 44535    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -166     |
# |    exploration rate | 0.573    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 8912     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 44936    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.6     |
# |    ep_rew_mean      | -163     |
# |    exploration rate | 0.57     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 8916     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 45302    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -163     |
# |    exploration rate | 0.566    |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 8921     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 45661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -162     |
# |    exploration rate | 0.563    |
# | time/               |          |
# |    episodes         | 500      |
# ...
# |    time_elapsed     | 584      |
# |    total timesteps  | 947705   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.07     |
# |    n_updates        | 1236346  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 450      |
# |    ep_rew_mean      | 238      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2848     |
# |    fps              | 1619     |
# |    time_elapsed     | 586      |
# |    total timesteps  | 949972   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.53     |
# |    n_updates        | 1236912  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 452      |
# |    ep_rew_mean      | 235      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2852     |
# |    fps              | 1618     |
# |    time_elapsed     | 588      |
# |    total timesteps  | 952047   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.424    |
# |    n_updates        | 1237431  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 447      |
# |    ep_rew_mean      | 236      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2856     |
# |    fps              | 1619     |
# |    time_elapsed     | 588      |
# |    total timesteps  | 953223   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.297    |
# |    n_updates        | 1237725  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 442      |
# |    ep_rew_mean      | 234      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2860     |
# |    fps              | 1617     |
# |    time_elapsed     | 590      |
# |    total timesteps  | 955025   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.363    |
# |    n_updates        | 1238176  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 442      |
# |    ep_rew_mean      | 234      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2864     |
# |    fps              | 1617     |
# |    time_elapsed     | 591      |
# |    total timesteps  | 956741   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.497    |
# |    n_updates        | 1238605  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 434      |
# |    ep_rew_mean      | 236      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2868     |
# |    fps              | 1617     |
# |    time_elapsed     | 592      |
# |    total timesteps  | 958239   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.735    |
# |    n_updates        | 1238979  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | 235      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2872     |
# |    fps              | 1617     |
# |    time_elapsed     | 593      |
# |    total timesteps  | 959770   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.405    |
# |    n_updates        | 1239362  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 424      |
# |    ep_rew_mean      | 235      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2876     |
# |    fps              | 1617     |
# |    time_elapsed     | 594      |
# |    total timesteps  | 961127   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.815    |
# |    n_updates        | 1239701  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 416      |
# |    ep_rew_mean      | 236      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2880     |
# |    fps              | 1617     |
# |    time_elapsed     | 595      |
# |    total timesteps  | 962954   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.36     |
# |    n_updates        | 1240158  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 421      |
# |    ep_rew_mean      | 236      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2884     |
# |    fps              | 1616     |
# |    time_elapsed     | 597      |
# |    total timesteps  | 965002   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.612    |
# |    n_updates        | 1240670  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 422      |
# |    ep_rew_mean      | 236      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2888     |
# |    fps              | 1615     |
# |    time_elapsed     | 598      |
# |    total timesteps  | 966472   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.937    |
# |    n_updates        | 1241037  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 425      |
# |    ep_rew_mean      | 235      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2892     |
# |    fps              | 1615     |
# |    time_elapsed     | 599      |
# |    total timesteps  | 968539   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.46     |
# |    n_updates        | 1241554  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 427      |
# |    ep_rew_mean      | 235      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2896     |
# |    fps              | 1615     |
# |    time_elapsed     | 600      |
# |    total timesteps  | 970475   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.316    |
# |    n_updates        | 1242038  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 431      |
# |    ep_rew_mean      | 235      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2900     |
# |    fps              | 1615     |
# |    time_elapsed     | 602      |
# |    total timesteps  | 972450   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.54     |
# |    n_updates        | 1242532  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 233      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2904     |
# |    fps              | 1614     |
# |    time_elapsed     | 603      |
# |    total timesteps  | 974411   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.653    |
# |    n_updates        | 1243022  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 425      |
# |    ep_rew_mean      | 235      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2908     |
# |    fps              | 1614     |
# |    time_elapsed     | 604      |
# |    total timesteps  | 975924   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.8      |
# |    n_updates        | 1243400  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 430      |
# |    ep_rew_mean      | 234      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2912     |
# |    fps              | 1613     |
# |    time_elapsed     | 605      |
# |    total timesteps  | 977821   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.511    |
# |    n_updates        | 1243875  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 440      |
# |    ep_rew_mean      | 233      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2916     |
# |    fps              | 1612     |
# |    time_elapsed     | 607      |
# |    total timesteps  | 980168   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.358    |
# |    n_updates        | 1244461  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 440      |
# |    ep_rew_mean      | 231      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2920     |
# |    fps              | 1612     |
# |    time_elapsed     | 609      |
# |    total timesteps  | 982507   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.54     |
# |    n_updates        | 1245046  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 434      |
# |    ep_rew_mean      | 229      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2924     |
# |    fps              | 1612     |
# |    time_elapsed     | 609      |
# |    total timesteps  | 983588   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.35     |
# |    n_updates        | 1245316  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 447      |
# |    ep_rew_mean      | 229      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2928     |
# |    fps              | 1611     |
# |    time_elapsed     | 611      |
# |    total timesteps  | 986201   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.163    |
# |    n_updates        | 1245970  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 439      |
# |    ep_rew_mean      | 232      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2932     |
# |    fps              | 1612     |
# |    time_elapsed     | 612      |
# |    total timesteps  | 987396   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.07     |
# |    n_updates        | 1246268  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 443      |
# |    ep_rew_mean      | 232      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2936     |
# |    fps              | 1612     |
# |    time_elapsed     | 613      |
# |    total timesteps  | 989127   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.37     |
# |    n_updates        | 1246701  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 441      |
# |    ep_rew_mean      | 233      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2940     |
# |    fps              | 1612     |
# |    time_elapsed     | 614      |
# |    total timesteps  | 990249   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.249    |
# |    n_updates        | 1246982  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 441      |
# |    ep_rew_mean      | 232      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2944     |
# |    fps              | 1612     |
# |    time_elapsed     | 615      |
# |    total timesteps  | 991792   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.307    |
# |    n_updates        | 1247367  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 431      |
# |    ep_rew_mean      | 235      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2948     |
# |    fps              | 1613     |
# |    time_elapsed     | 615      |
# |    total timesteps  | 993048   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.527    |
# |    n_updates        | 1247681  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 423      |
# |    ep_rew_mean      | 239      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2952     |
# |    fps              | 1613     |
# |    time_elapsed     | 616      |
# |    total timesteps  | 994368   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.381    |
# |    n_updates        | 1248011  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 430      |
# |    ep_rew_mean      | 238      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2956     |
# |    fps              | 1613     |
# |    time_elapsed     | 617      |
# |    total timesteps  | 996263   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.206    |
# |    n_updates        | 1248485  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 427      |
# |    ep_rew_mean      | 240      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2960     |
# |    fps              | 1613     |
# |    time_elapsed     | 618      |
# |    total timesteps  | 997692   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.226    |
# |    n_updates        | 1248842  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 420      |
# |    ep_rew_mean      | 239      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2964     |
# |    fps              | 1613     |
# |    time_elapsed     | 618      |
# |    total timesteps  | 998742   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.733    |
# |    n_updates        | 1249105  |
# ----------------------------------

# %% [markdown]
# ## Step 4 : RL performance evaluation

# %%
# Evaluate rewards of X episodes
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=50)
print(f"mean_reward = {mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward = 206.94 +/- 66.29538645610968

# %%
# Evaluate score of X episodes
episodes = 10
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        # action = env.action_space.sample()
        action, _states = model.predict(state, deterministic=True)
        state, reward, done, info = env.step(action)
        score += reward
        env.render()
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:253.03489491225028
# Episode:2 Score:241.82517805466304
# Episode:3 Score:124.11066242996381
# Episode:4 Score:111.84710417887614
# Episode:5 Score:182.53179117837925
# Episode:6 Score:228.1282998993443
# Episode:7 Score:223.57938434818303
# Episode:8 Score:247.12375418244366
# Episode:9 Score:284.8110964051093
# Episode:10 Score:250.41523609771204

# %%
# render X episodes
evaluate_policy(model, env, n_eval_episodes=5, render=True)
env.close()

# %%
# render 1 episode
obs = env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    env.render()
    # env_screen = env.render(mode='rgb_array')  # collect frame of the env.
    if done:
        print("done at", i)
        break
env.close()
# plt.imshow(env_screen)
# Out:
# done at 489

# %% [markdown]
# ## Step 5 : save RL model

# %%
# Save the agent
model.save("dqn_lunar_X")

# %%
del model

# %%
# Load the trained agent
model = DQN.load("dqn_lunar_2", env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.policy
# Out:
# DQNPolicy(
#   (q_net): QNetwork(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=8, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=4, bias=True)
#     )
#   )
#   (q_net_target): QNetwork(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=8, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=4, bias=True)
#     )
#   )
# )

# %% [markdown]
# # ENV modifications (optional)

# %% [markdown]
# ## Step 1 : Explore Observation and Action Spaces

# %%
obs_space = env.observation_space
action_space = env.action_space
print("The observation space: ", obs_space)
print("The action space: ", action_space)
# Out:
# The observation space:  Box([-inf -inf -inf -inf -inf -inf -inf -inf], [inf inf inf inf inf inf inf inf], (8,), float32)
# The action space:  Discrete(4)

# %%
print("Upper Bound for Env Observation", obs_space.high)
print("Lower Bound for Env Observation", obs_space.low)
# Out:
# Upper Bound for Env Observation [inf inf inf inf inf inf inf inf]
# Lower Bound for Env Observation [-inf -inf -inf -inf -inf -inf -inf -inf]

# %%
print("The observation space's shape: ", obs_space.shape)
# Out:
# The observation space's shape:  (8,)

# %%
# Explore action_space

env.reset()

# Works
env.step(2)
print("It works!")

# Doesn't work (Discrete(4) have actions 0-3)
env.step(4)
print("It works!")
# Out:
# It works!
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /var/folders/rd/xnkdmhqx0c19zv0s0z9zcc9c0000gn/T/ipykernel_32770/921668977.py in <module>
#       8
#       9 # Doesn't work (Discrete(4) have actions 0-3)
# ---> 10 env.step(4)
#      11 print("It works!")
#
# ~/Desktop/Eyp/codebases/RL_gym_tutorial/env/lib/python3.9/site-packages/gym/wrappers/time_limit.py in step(self, action)
#      16             self._elapsed_steps is not None
#      17         ), "Cannot call env.step() before calling reset()"
# ---> 18         observation, reward, done, info = self.env.step(action)
#      19         self._elapsed_steps += 1
#      20         if self._elapsed_steps >= self._max_episode_steps:
#
# ~/Desktop/Eyp/codebases/RL_gym_tutorial/env/lib/python3.9/site-packages/gym/envs/box2d/lunar_lander.py in step(self, action)
#     266             action = np.clip(action, -1, +1).astype(np.float32)
#     267         else:
# --> 268             assert self.action_space.contains(action), "%r (%s) invalid " % (
#     269                 action,
#     270                 type(action),
#
# AssertionError: 4 (<class 'int'>) invalid

# %% [markdown]
# ## Step 2 : Apply Wrapper

# %% [markdown]
# ### vanilla wrapper
# objective: make time-series observation_space

# %%
from collections import deque
from gym import spaces
import numpy as np

class ConcatObs(gym.Wrapper):
    def __init__(self, env, k):
        gym.Wrapper.__init__(self, env)
        self.k = k
        self.frames = deque([], maxlen=k)
        shp = env.observation_space.shape
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=((k,) + shp), dtype=env.observation_space.dtype)

    def reset(self):
        ob = self.env.reset()
        for _ in range(self.k):
            self.frames.append(ob)
        return self._get_ob()

    def step(self, action):
        ob, reward, done, info = self.env.step(action)
        self.frames.append(ob)
        return self._get_ob(), reward, done, info

    def _get_ob(self):
        return np.array(self.frames)

    def test(self):
        print("test")

# %%
env_name = 'LunarLander-v2'
env = gym.make(env_name)
vanilla_wrapped_env = ConcatObs(env, 4)
print("The new observation space is", vanilla_wrapped_env.observation_space)
print("The new observation space's shape: ", vanilla_wrapped_env.observation_space.shape)
# Out:
# The new observation space is Box([[-inf -inf -inf -inf -inf -inf -inf -inf]
#  [-inf -inf -inf -inf -inf -inf -inf -inf]
#  [-inf -inf -inf -inf -inf -inf -inf -inf]
#  [-inf -inf -inf -inf -inf -inf -inf -inf]], [[inf inf inf inf inf inf inf inf]
#  [inf inf inf inf inf inf inf inf]
#  [inf inf inf inf inf inf inf inf]
#  [inf inf inf inf inf inf inf inf]], (4, 8), float32)
# The new observation space's shape:  (4, 8)

# %%
# class attributes and methods
print([temp for temp in dir(vanilla_wrapped_env) if not temp.startswith("_")])
# Out:
# ['action_space', 'class_name', 'close', 'compute_reward', 'env', 'frames', 'k', 'metadata', 'observation_space', 'render', 'reset', 'reward_range', 'seed', 'spec', 'step', 'test', 'unwrapped']

# %%
# Reset the Env
obs = vanilla_wrapped_env.reset()
print("Intial obs is of the shape", obs.shape)
print(obs.round(2))

# Take one step
obs, _, _, _  = vanilla_wrapped_env.step(2)
print("Obs after taking a step is", obs.shape)
print(obs.round(2))
# Out:
# Intial obs is of the shape (4, 8)
# [[-0.    1.41 -0.37 -0.11  0.    0.08  0.    0.  ]
#  [-0.    1.41 -0.37 -0.11  0.    0.08  0.    0.  ]
#  [-0.    1.41 -0.37 -0.11  0.    0.08  0.    0.  ]
#  [-0.    1.41 -0.37 -0.11  0.    0.08  0.    0.  ]]
# Obs after taking a step is (4, 8)
# [[-0.    1.41 -0.37 -0.11  0.    0.08  0.    0.  ]
#  [-0.    1.41 -0.37 -0.11  0.    0.08  0.    0.  ]
#  [-0.    1.41 -0.37 -0.11  0.    0.08  0.    0.  ]
#  [-0.01  1.41 -0.39 -0.09  0.01  0.07  0.    0.  ]]

# %% [markdown]
# ### specific wrappers

# %%
import random

class ObservationWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
    
    def observation(self, obs):
        # Normalise observation by 255
        return obs / 255.0

    def test(self):
        print("test")
    
class RewardWrapper(gym.RewardWrapper):
    def __init__(self, env):
        super().__init__(env)
    
    def reward(self, reward):
        # Clip reward between 0 to 1
        return np.clip(reward, 0, 1)
    
class ActionWrapper(gym.ActionWrapper):
    def __init__(self, env):
        super().__init__(env)
    
    def action(self, action):
        if action == 2:
            return random.choice([0,1,3])
        else:
            return action

# %%
env_name = 'LunarLander-v2'
env = gym.make(env_name)
wrapped_env = ObservationWrapper(RewardWrapper(ActionWrapper(env)))

# %%
obs = wrapped_env.reset()

for i in range(500):
    action = wrapped_env.action_space.sample()
    obs, reward, done, info = wrapped_env.step(action)
    
    # Raise a flag if values have not been vectorised properly
    if (obs > 2.0).any() or (obs < -2.0).any():
        print("Max or min value of observations out of range")
    
    # Raise a flag if reward has not been clipped.
    if reward < 0.0 or reward > 1.0:
        assert False, "Reward out of bounds"
    
    # Check the rendering if the spaceship don't fire the main engine
    wrapped_env.render()
    
    # if done:
    #     print("done at", i)
    #     break

wrapped_env.close()

print("All checks passed")
# Out:
# All checks passed

# %%
# class attributes and methods
print([temp for temp in dir(wrapped_env) if not temp.startswith("_")])
# Out:
# ['action_space', 'class_name', 'close', 'compute_reward', 'env', 'metadata', 'observation', 'observation_space', 'render', 'reset', 'reward_range', 'seed', 'spec', 'step', 'test', 'unwrapped']

# %% [markdown]
# ## Step 3 : Vectorized Environment

# %%
import gym
from stable_baselines3.common.vec_env.subproc_vec_env import SubprocVecEnv

# List of Env
num_envs = 3
env_name = 'LunarLander-v2'
envs = [lambda: gym.make(env_name) for i in range(num_envs)]

# Vec Env 
envs = SubprocVecEnv(envs)

# %%
# Get initial state
init_obs = envs.reset()

# We get a list of observations corresponding to parallel environments 
print("Number of Envs:", len(init_obs))
print(init_obs)

# Check out of the obs 
one_obs = init_obs[0]
print("\nShape of one Env:", one_obs.shape)
print(one_obs)

# prepare a list of actions and apply them to each environment 
actions = [0, 1, 2]
obs, rewards, dones, _ = envs.step(actions)
print("\nResults of step function:")
print("obs: ", obs)
print("rewards: ", rewards)
print("dones: ", dones)
# Out:
# Number of Envs: 3
# [[ 2.0866394e-04  1.4159008e+00  2.1123327e-02  2.2136579e-01
#   -2.3503168e-04 -4.7847279e-03  0.0000000e+00  0.0000000e+00]
#  [-6.9787027e-03  1.4141301e+00 -7.0688903e-01  1.4264348e-01
#    8.0934241e-03  1.6012080e-01  0.0000000e+00  0.0000000e+00]
#  [ 6.8333624e-03  1.3996953e+00  6.9212472e-01 -4.9890202e-01
#   -7.9113161e-03 -1.5677658e-01  0.0000000e+00  0.0000000e+00]]
#
# Shape of one Env: (8,)
# [ 2.0866394e-04  1.4159008e+00  2.1123327e-02  2.2136579e-01
#  -2.3503168e-04 -4.7847279e-03  0.0000000e+00  0.0000000e+00]
#
# Results of step function:
# obs:  [[ 4.1723251e-04  1.4203035e+00  2.1094989e-02  1.9567196e-01
#   -4.7141171e-04 -4.7273817e-03  0.0000000e+00  0.0000000e+00]
#  [-1.4029121e-02  1.4167694e+00 -7.1484143e-01  1.1721561e-01
#    1.7791443e-02  1.9397831e-01  0.0000000e+00  0.0000000e+00]
#  [ 1.3715362e-02  1.3892778e+00  6.9584286e-01 -4.6305344e-01
#   -1.5459266e-02 -1.5097317e-01  0.0000000e+00  0.0000000e+00]]
# rewards:  [ 2.09264548 -1.59399329  1.7180019 ]
# dones:  [False False False]

# %%
init_obs = envs.reset()

for i in range(1000):
    actions = [envs.action_space.sample() for i in range(num_envs)]
    envs.step(actions)
    envs.render()

envs.close()
